# %% [markdown]
# ## Weather Data Analysis Real World Project

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### import data

# %%
weather_df = pd.read_csv('data/1. Weather Data.csv')
weather_df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# #### Data Preview

# %%
weather_df.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
weather_df.tail()
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa Weather
# 8779            9.7     100.13    Snow
# 8780            9.7     100.03    Snow
# 8781            4.8      99.95    Snow
# 8782            9.7      99.91    Snow
# 8783           11.3      99.89    Snow

# %%
weather_df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
weather_df.shape
# Out:
# (8784, 8)

# %%
weather_df.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
weather_df.Weather.unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
weather_df.Weather.nunique()
# Out:
# 50

# %%
weather_df.Weather.value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %% [markdown]
# #### Data Preprocessing

# %%
weather_df['Date/Time'].duplicated().sum()
# Out:
# 0

# %%
weather_df['Date/Time'] = pd.to_datetime(weather_df['Date/Time'])
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   datetime64[ns]
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(1)
# memory usage: 549.1+ KB

# %%
weather_df.isna().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
weather_df.rename(columns={"Date/Time":"Date_Time","Dew Point Temp_C":"Dew_Point_Temp_C" , "Rel Hum_%" : "Rel_Hum_in_%" , "Wind Speed_km/h": "Wind_Speed_KM/H" , "Weather": "Weather_Condition"},inplace=True)

# %%
weather_df.describe()
# Out:
#             Temp_C  Dew_Point_Temp_C  Rel_Hum_in_%  Wind_Speed_KM/H  \
# count  8784.000000       8784.000000   8784.000000      8784.000000
# mean      8.798144          2.555294     67.431694        14.945469
# std      11.687883         10.883072     16.918881         8.688696
# min     -23.300000        -28.500000     18.000000         0.000000
# 25%       0.100000         -5.900000     56.000000         9.000000
# 50%       9.300000          3.300000     68.000000        13.000000
# 75%      18.800000         11.800000     81.000000        20.000000
# max      33.000000         24.400000    100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
weather_df[weather_df['Wind_Speed_KM/H'] == 0]
# i was thinking wind speed it can't be zero , and this values is invalid or null values but after research i found yeah it is possible to be zero near to ground for more check this: https://www.quora.com/Can-wind-speed-be-zero
# Out:
#                Date_Time  Temp_C  Dew_Point_Temp_C  Rel_Hum_in_%  \
# 97   2012-01-05 01:00:00    -7.5             -10.2            81
# 123  2012-01-06 03:00:00   -10.6             -16.0            64
# 145  2012-01-07 01:00:00    -8.5             -11.4            80
# 160  2012-01-07 16:00:00    -3.6              -5.9            84
# 165  2012-01-07 21:00:00    -1.3              -3.1            88
# ...                  ...     ...               ...           ...
# 7942 2012-11-26 22:00:00    -5.4              -9.6            72
# 8028 2012-11-30 12:00:00    -9.3             -15.2            62
# 8108 2012-12-03 20:00:00     3.5               0.7            82
# 8212 2012-12-08 04:00:00     2.5              -1.2            77
# 8767 2012-12-31 07:00:00    -9.3             -11.3            85
#
#       Wind_Speed_KM/H  Visibility_km  Press_kPa Weather_Condition
# 97                  0            9.7     100.29              Snow
# ...

# %% [markdown]
# #### data is already cleaned from source but we did a little things on it

# %% [markdown]
# ## EDA ِAnd Anlysis

# %% [markdown]
# #### Q1: Find all unique "Wind Speed" Value in the data

# %%
weather_df['Wind_Speed_KM/H'].describe()
# Out:
# count    8784.000000
# mean       14.945469
# std         8.688696
# min         0.000000
# 25%         9.000000
# 50%        13.000000
# 75%        20.000000
# max        83.000000
# Name: Wind_Speed_KM/H, dtype: float64

# %%
weather_df['Wind_Speed_KM/H'].nunique()
# Out:
# 34

# %%
weather_df['Wind_Speed_KM/H'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %% [markdown]
# #### A1: There are 34 value of wind speed start from 0 to 83 , and all values in the prev array

# %% [markdown]
# #### Q2 : Find Number of Times when the weather is exactly clear

# %%
weather_df['Weather_Condition'].value_counts()
#Clear: 1326
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
len(weather_df[weather_df['Weather_Condition'] == 'Clear'])
#Clear: 1326
# Out:
# 1326

# %%
weather_df.groupby('Weather_Condition')['Weather_Condition'].count()
#Clear: 1326
# Out:
# Weather_Condition
# Clear                                      1326
# Cloudy                                     1728
# Drizzle                                      41
# Drizzle,Fog                                  80
# Drizzle,Ice Pellets,Fog                       1
# Drizzle,Snow                                  2
# Drizzle,Snow,Fog                             15
# Fog                                         150
# Freezing Drizzle                              7
# Freezing Drizzle,Fog                          6
# Freezing Drizzle,Haze                         3
# Freezing Drizzle,Snow                        11
# Freezing Fog                                  4
# Freezing Rain                                14
# Freezing Rain,Fog                             4
# Freezing Rain,Haze                            2
# Freezing Rain,Ice Pellets,Fog                 1
# Freezing Rain,Snow Grains                     1
# Haze                                         16
# ...

# %% [markdown]
# #### A2: using these 3 methods we found the answer is 1326

# %% [markdown]
# #### Q3: Find the number of times when the wind speed was excalty 4 km\h

# %%
weather_df[weather_df['Wind_Speed_KM/H'] == 4]
# Out:
#                Date_Time  Temp_C  Dew_Point_Temp_C  Rel_Hum_in_%  \
# 0    2012-01-01 00:00:00    -1.8              -3.9            86
# 1    2012-01-01 01:00:00    -1.8              -3.7            87
# 96   2012-01-05 00:00:00    -8.8             -11.7            79
# 101  2012-01-05 05:00:00    -7.0              -9.5            82
# 146  2012-01-07 02:00:00    -8.1             -11.1            79
# ...                  ...     ...               ...           ...
# 8768 2012-12-31 08:00:00    -8.6             -10.3            87
# 8769 2012-12-31 09:00:00    -8.1              -9.6            89
# 8770 2012-12-31 10:00:00    -7.4              -8.9            89
# 8772 2012-12-31 12:00:00    -5.8              -7.5            88
# 8773 2012-12-31 13:00:00    -4.6              -6.6            86
#
#       Wind_Speed_KM/H  Visibility_km  Press_kPa Weather_Condition
# 0                   4            8.0     101.24               Fog
# ...

# %%
len(weather_df[weather_df['Wind_Speed_KM/H'] == 4])
# Out:
# 474

# %% [markdown]
# #### A3 : it is 474 Record in data-set

# %% [markdown]
# #### Q4: What is mean of Visibility

# %%
weather_df['Visibility_km'].mean()
# Out:
# 27.66444672131151

# %% [markdown]
# #### A5 : Mean is 27.664

# %% [markdown]
# #### Q5: What is Standard Deviation of plessure in this data

# %%
weather_df['Press_kPa'].std()
# Out:
# 0.8440047459486474

# %% [markdown]
# #### A5 : Standard Deviation is 0.844

# %% [markdown]
# #### Q6: What is the varince of Relative Humidity in this data

# %%
weather_df['Rel_Hum_in_%'].var()
# Out:
# 286.2485501984998

# %% [markdown]
# #### A6: Varince is 286.24

# %% [markdown]
# #### Q7: Find all instance when snow recorded

# %%
weather_df[weather_df.Weather_Condition == 'Snow']
# Out:
#                Date_Time  Temp_C  Dew_Point_Temp_C  Rel_Hum_in_%  \
# 55   2012-01-03 07:00:00   -14.0             -19.5            63
# 84   2012-01-04 12:00:00   -13.7             -21.7            51
# 86   2012-01-04 14:00:00   -11.3             -19.0            53
# 87   2012-01-04 15:00:00   -10.2             -16.3            61
# 88   2012-01-04 16:00:00    -9.4             -15.5            61
# ...                  ...     ...               ...           ...
# 8779 2012-12-31 19:00:00     0.1              -2.7            81
# 8780 2012-12-31 20:00:00     0.2              -2.4            83
# 8781 2012-12-31 21:00:00    -0.5              -1.5            93
# 8782 2012-12-31 22:00:00    -0.2              -1.8            89
# 8783 2012-12-31 23:00:00     0.0              -2.1            86
#
#       Wind_Speed_KM/H  Visibility_km  Press_kPa Weather_Condition
# 55                 19           25.0     100.95              Snow
# ...

# %% [markdown]
# #### it is all records when Weather_Condition is excatly snow , but we will get if it contains snow

# %%
weather_df[weather_df.Weather_Condition.str.contains('Snow')]
# Out:
#                Date_Time  Temp_C  Dew_Point_Temp_C  Rel_Hum_in_%  \
# 41   2012-01-02 17:00:00    -2.1              -9.5            57
# 44   2012-01-02 20:00:00    -5.6             -13.4            54
# 45   2012-01-02 21:00:00    -5.8             -12.8            58
# 47   2012-01-02 23:00:00    -7.4             -14.1            59
# 48   2012-01-03 00:00:00    -9.0             -16.0            57
# ...                  ...     ...               ...           ...
# 8779 2012-12-31 19:00:00     0.1              -2.7            81
# 8780 2012-12-31 20:00:00     0.2              -2.4            83
# 8781 2012-12-31 21:00:00    -0.5              -1.5            93
# 8782 2012-12-31 22:00:00    -0.2              -1.8            89
# 8783 2012-12-31 23:00:00     0.0              -2.1            86
#
#       Wind_Speed_KM/H  Visibility_km  Press_kPa Weather_Condition
# 41                 22           25.0      99.66      Snow Showers
# ...

# %% [markdown]
# #### A7: all records when Weather_Condition is excatly snow is 390 Row
# #### but all records when Weather_Condition contain snow is 583 Row

# %% [markdown]
# #### Q8 : what is the mean of wind speed for each Weather Condition

# %%
weather_df.groupby('Weather_Condition')['Wind_Speed_KM/H'].mean()
# Out:
# Weather_Condition
# Clear                                      10.557315
# Cloudy                                     16.127315
# Drizzle                                    16.097561
# Drizzle,Fog                                11.862500
# Drizzle,Ice Pellets,Fog                    20.000000
# Drizzle,Snow                               14.000000
# Drizzle,Snow,Fog                           15.533333
# Fog                                         7.946667
# Freezing Drizzle                           16.571429
# Freezing Drizzle,Fog                       17.000000
# Freezing Drizzle,Haze                      10.333333
# Freezing Drizzle,Snow                      16.272727
# Freezing Fog                                4.750000
# Freezing Rain                              19.214286
# Freezing Rain,Fog                          15.500000
# Freezing Rain,Haze                          7.500000
# Freezing Rain,Ice Pellets,Fog              28.000000
# ...

# %%
weather_df.groupby('Weather_Condition')['Wind_Speed_KM/H'].mean().sort_values()
# Out:
# Weather_Condition
# Freezing Fog                                4.750000
# Snow,Haze                                   5.000000
# Freezing Rain,Haze                          7.500000
# Thunderstorms                               7.500000
# Fog                                         7.946667
# Thunderstorms,Heavy Rain Showers            9.000000
# Rain,Snow,Fog                               9.000000
# Freezing Drizzle,Haze                      10.333333
# Haze                                       10.437500
# Clear                                      10.557315
# Rain,Haze                                  11.666667
# Drizzle,Fog                                11.862500
# Rain Showers,Fog                           13.000000
# Snow Showers,Fog                           13.750000
# Drizzle,Snow                               14.000000
# Mainly Clear                               14.144824
# Rain,Fog                                   14.793103
# ...

# %% [markdown]
# #### A8 : this table contain the mean of wind speed for each weather condition and sorted from low to high

# %% [markdown]
# #### Q9: Find all instances when 'Weather is Clear' or 'Visibility is above 40'.

# %%
weather_df[(weather_df.Weather_Condition == 'Clear') | (weather_df.Visibility_km > 40)]
# Out:
#                Date_Time  Temp_C  Dew_Point_Temp_C  Rel_Hum_in_%  \
# 67   2012-01-03 19:00:00   -16.9             -24.8            50
# 106  2012-01-05 10:00:00    -6.0             -10.0            73
# 107  2012-01-05 11:00:00    -5.6             -10.2            70
# 108  2012-01-05 12:00:00    -4.7              -9.6            69
# 109  2012-01-05 13:00:00    -4.4              -9.7            66
# ...                  ...     ...               ...           ...
# 8749 2012-12-30 13:00:00   -12.4             -16.2            73
# 8750 2012-12-30 14:00:00   -11.8             -16.1            70
# 8751 2012-12-30 15:00:00   -11.3             -15.6            70
# 8752 2012-12-30 16:00:00   -11.4             -15.5            72
# 8756 2012-12-30 20:00:00   -13.8             -16.5            80
#
#       Wind_Speed_KM/H  Visibility_km  Press_kPa Weather_Condition
# 67                 24           25.0     101.74             Clear
# ...

# %% [markdown]
# #### Q10 : find the mean of each column against weather condition

# %%
weather_df.groupby('Weather_Condition').mean()
# Out:
#                                             Temp_C  Dew_Point_Temp_C  \
# Weather_Condition
# Clear                                     6.825716          0.089367
# Cloudy                                    7.970544          2.375810
# Drizzle                                   7.353659          5.504878
# Drizzle,Fog                               8.067500          7.033750
# Drizzle,Ice Pellets,Fog                   0.400000         -0.700000
# Drizzle,Snow                              1.050000          0.150000
# Drizzle,Snow,Fog                          0.693333          0.120000
# Fog                                       4.303333          3.159333
# Freezing Drizzle                         -5.657143         -8.000000
# Freezing Drizzle,Fog                     -2.533333         -4.183333
# Freezing Drizzle,Haze                    -5.433333         -8.000000
# Freezing Drizzle,Snow                    -5.109091         -7.072727
# ...

# %% [markdown]
# #### Q11: FInd the lowest and highest Month in the year in mean Temp

# %%
weather_df['Month'] = weather_df['Date_Time'].dt.month

# %%
months_temp_ser = weather_df.groupby('Month')['Temp_C'].mean()
months_temp_ser
# Out:
# Month
# 1     -7.371505
# 2     -4.225000
# 3      3.121237
# 4      7.009306
# 5     16.237769
# 6     20.134028
# 7     22.790054
# 8     22.279301
# 9     16.484444
# 10    10.954973
# 11     0.931389
# 12    -3.306317
# Name: Temp_C, dtype: float64

# %%
months_temp_ser.sort_values()
# Out:
# Month
# 1     -7.371505
# 2     -4.225000
# 12    -3.306317
# 11     0.931389
# 3      3.121237
# 4      7.009306
# 10    10.954973
# 5     16.237769
# 9     16.484444
# 6     20.134028
# 8     22.279301
# 7     22.790054
# Name: Temp_C, dtype: float64

# %% [markdown]
# #### A11: Highest Month in the year in July and lowest month is January

# %% [markdown]
# #### Q12 : Create chart how temp change daily

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
weather_df['Date_Time']
# Out:
# 0      2012-01-01 00:00:00
# 1      2012-01-01 01:00:00
# 2      2012-01-01 02:00:00
# 3      2012-01-01 03:00:00
# 4      2012-01-01 04:00:00
#                ...
# 8779   2012-12-31 19:00:00
# 8780   2012-12-31 20:00:00
# 8781   2012-12-31 21:00:00
# 8782   2012-12-31 22:00:00
# 8783   2012-12-31 23:00:00
# Name: Date_Time, Length: 8784, dtype: datetime64[ns]

# %%
weather_df['Temp_C']
# Out:
# 0      -1.8
# 1      -1.8
# 2      -1.8
# 3      -1.5
# 4      -1.5
#        ...
# 8779    0.1
# 8780    0.2
# 8781   -0.5
# 8782   -0.2
# 8783    0.0
# Name: Temp_C, Length: 8784, dtype: float64

# %%
plt.figure(figsize=(20,10))
plt.plot(weather_df['Date_Time'] ,weather_df['Temp_C'])
plt.title('Temp Over Year' ,)
plt.ylabel('Temp_C')
# Out:
# Text(0, 0.5, 'Temp_C')

# %% [markdown]
# #### Q13: Check if there correlation between wind speed and temp

# %%
plt.figure(figsize=(20,10))
plt.scatter(weather_df['Temp_C'] , weather_df['Wind_Speed_KM/H'])

# %%
plt.figure(figsize=(20,10))
plt.plot(weather_df['Date_Time'] , weather_df['Wind_Speed_KM/H'].rolling(30).mean())
plt.plot(weather_df['Date_Time'] , weather_df['Temp_C'].rolling(30).mean())

# %% [markdown]
# #### A13: The only relationship between them is that when the temperature is close to zero, the wind speed reaches its highest level Other than that, there is no relationship between them
